# %% [markdown]
# 打印出如下图案（菱形）:

# %%
#生成两个保存星星数量和空格数量的列表
starts_list = []
space_list = []
def make_list(n): #n表示星型最多那一行的行数(中间那一行），从0记起,本例中n=3
    for i in range(2*n+1):
        space = abs(i - n)
        starts = 2*n+1 - 2*space
        print(" " * space, "*" * starts, end="")
        print()

# %%
make_list(33)
# Out:
#                                   *
#                                  ***
#                                 *****
#                                *******
#                               *********
#                              ***********
#                             *************
#                            ***************
#                           *****************
#                          *******************
#                         *********************
#                        ***********************
#                       *************************
#                      ***************************
#                     *****************************
#                    *******************************
#                   *********************************
#                  ***********************************
#                 *************************************
#                ***************************************
# ...
